# %% [markdown]
# # question

# %% [markdown]
# 1.What is Simple Linear Regression?
# -
# It's a method to model the relationship between one independent variable (X) and one dependent variable (Y) using a straight line:
# 𝑌
# =
# 𝑚
# 𝑋

# %% [markdown]
# 2. What are the key assumptions of Simple Linear Regression?
# - Linearity
#
# - Independence of errors
#
# - Homoscedasticity (constant variance)
#
# - Normally distributed errors

# %% [markdown]
# 3. What does the coefficient m represent in the equation Y=mX+c?
# - It’s the slope, representing the change in Y for a one-unit change in X.

# %% [markdown]
# 4. What does the intercept c represent in the equation Y=mX+c?
# - It's the value of Y when X = 0.

# %% [markdown]
# 5. How do we calculate the slope m in Simple Linear Regression?
#
# - ∑(X−
# X
# ˉ
#  )(Y−
# Y
# ˉ
#  )/∑(X−
# X
# ˉ
#  )
# 2

# %% [markdown]
# 6. What is the purpose of the least squares method in Simple Linear Regression?
# - To minimize the sum of squared differences between observed and predicted Y values.

# %% [markdown]
# 7. How is the coefficient of determination (R²) interpreted in Simple Linear Regression?
# - It indicates the proportion of variance in Y explained by X; values range from 0 to 1.

# %% [markdown]
# 8. What is Multiple Linear Regression?
# - A method to model the relationship between multiple independent variables and one dependent variable.

# %% [markdown]
# 9. What is the main difference between Simple and Multiple Linear Regression?
# - Simple uses one independent variable; multiple uses two or more.

# %% [markdown]
# 10. What are the key assumptions of Multiple Linear Regression?
# - Same as simple regression plus no multicollinearity among predictors.

# %% [markdown]
# 11. What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model?
# - Heteroscedasticity refers to the condition where the variance of the residuals (errors) is not constant across all levels of the independent variables. In simpler terms, the spread of the errors changes depending on the value of X.
#
# - Effect on regression results
# -It violates one of the key assumptions of linear regression (constant variance of errors).
# -Leads to inefficient estimates of regression coefficients.
# -Standard errors become biased, which affects the reliability of hypothesis tests (like t-tests).

# %% [markdown]
# 12. How can you improve a Multiple Linear Regression model with high multicollinearity?
# - Remove correlated variables
#
# - Use Principal Component Analysis (PCA)
#
# - Regularization (Ridge/Lasso)

# %% [markdown]
# 13. What are some common techniques for transforming categorical variables for use in regression models?
# - One-hot encoding
#
# - Label encoding
#
# - Binary encoding

# %% [markdown]
# 14. What is the role of interaction terms in Multiple Linear Regression?
# - Capture combined effects of two variables on the outcome.

# %% [markdown]
# 15. How can the interpretation of intercept differ between Simple and Multiple Linear Regression?
# - In simple regression, it's Y at X=0; in multiple regression, it’s Y when all Xs are 0 (often not meaningful).

# %% [markdown]
# 16. What is the significance of the slope in regression analysis, and how does it affect predictions?
# - Indicates how much Y changes per unit change in X.

# %% [markdown]
# 17. How does the intercept in a regression model provide context for the relationship between variables?
# - Helps understand baseline value of Y before changes in X.

# %% [markdown]
# 18. What are the limitations of using R² as a sole measure of model performance?
# - Doesn’t account for overfitting or variable count; adjusted R² is better for multiple regression.

# %% [markdown]
# 19. How would you interpret a large standard error for a regression coefficient?
# - Suggests low confidence in the coefficient estimate.

# %% [markdown]
# 20. How can heteroscedasticity be identified in residual plots, and why is it important to address it?
# - Look for funnel shapes; addressing it improves model accuracy.

# %% [markdown]
# 21.What does it mean if a Multiple Linear Regression model has a high R² but low adjusted R²?
# - Indicates overfitting or inclusion of irrelevant variables.

# %% [markdown]
# 22. Why is it important to scale variables in Multiple Linear Regression?
# - Helps algorithms converge faster and gives equal importance to features.

# %% [markdown]
# 23. What is polynomial regression?
# - A regression where the relationship is modeled as an nth-degree polynomial.

# %% [markdown]
# 24. How does polynomial regression differ from linear regression?
# - Polynomial regression differs from linear regression in the form of the relationship it models:
# -Linear regression models a straight-line relationship between the independent variable
# -X and the dependent variable
#
# Y=mX+cY = mX + cY=mX+c.
# - Polynomial regression models a curved or non-linear relationship using polynomial terms (like
# X2,X3,…X^2, X^3, \ldotsX2,X3,…), i.e.,
#
# Y=a+bX+cX2+dX3+…+nXkY = a + bX + cX^2 + dX^3 + \ldots + nX^kY=a+bX+cX2+dX3+…+nXk

# %% [markdown]
# 25.When is polynomial regression used?
# - When data shows a curved trend.

# %% [markdown]
# 26. What is the general equation for polynomial regression?
# - Y=a+bX+cX
# 2
#  +dX
# 3
#  +…+nX
# k

# %% [markdown]
# 27.Can polynomial regression be applied to multiple variables?
# - Yes, known as multivariate polynomial regression.

# %% [markdown]
# 28. What are the limitations of polynomial regression?
# - Overfitting
#
# - Poor extrapolation
#
# - Complexity increases with degree

# %% [markdown]
# 29.What methods can be used to evaluate model fit when selecting the degree of a polynomial?
# - Use cross-validation, R², adjusted R², and AIC/BIC.

# %% [markdown]
# 30. Why is visualization important in polynomial regression�
# - Helps detect patterns, overfitting, and interpret the model.

# %% [markdown]
# 31.How is polynomial regression implemented in Python?
# - Using libraries like numpy, scikit-learn (PolynomialFeatures, LinearRegression
